# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
acc = pd.read_csv('acc.train.csv')
loss = pd.read_csv('loss.train.csv')
acc_val = pd.read_csv('acc.val.csv')

# %%
acc.plot()

# %%
fig, ax = plt.subplots(figsize=(10,8))
loss.plot(ax=ax)
plt.savefig('with-pos.pdf')

# %%
acc_val.plot()
# Out:
# /Users/daan/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2918: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
