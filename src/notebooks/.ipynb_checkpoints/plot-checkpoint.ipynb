# %%
import glob
import os

import pandas as pd
# %matplotlib inline

# %%
latest_dir = max(glob.glob(os.path.join('../log', '*/')))
loss_path = os.path.join(latest_dir, 'loss.csv')
loss = pd.read_csv(loss_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-9129f4982373> in <module>()
#       1 latest_dir = max(glob.glob(os.path.join('../log', '*/')))
#       2 loss_path = os.path.join(latest_dir, 'loss.csv')
# ----> 3 loss = pd.read_csv(loss_path)
#
# ...

# %%
loss.rolling(10).mean().plot()
