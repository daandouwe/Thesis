# %%
import csv
import pandas as pd

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("run/elbo.csv")
df.plot()

# %%
aer = pd.read_csv("run/aer.csv")
fig, ax = plt.subplots(figsize=(9, 6))
aer.plot(ax=ax)
plt.savefig('run/aer.pdf')

# %%
# Plot a running ('rolling') average of the values for more insight:
fig, ax = plt.subplots(figsize=(9, 6))
df.rolling(window=100, center=False).mean().plot(ax=ax)
plt.savefig('run/elbo.png')

# %%
df["elbo"].rolling(window=100, center=False).mean().plot()

# %%
# Plot a running ('rolling') average of the values for more insight:
df["log_px"].rolling(window=100, center=False).mean().plot()

# %%
# Plot a running ('rolling') average of the values for more insight:
df["log_py"].rolling(window=100, center=False).mean().plot()

# %%
# Plot a running ('rolling') average of the values for more insight:
df["-kl"].rolling(window=100, center=False).mean().plot()
