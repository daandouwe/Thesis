# %% [markdown]
# # Draw some parsed sentences

# %%
from nltk import Tree
from nltk.draw.tree import TreeView

# %% [markdown]
# ## Negative polarity

# %% [markdown]
# ### CRF parser

# %%
npi_pos = "(S (NP (NP The talk) (SBAR (S (NP I) (VP gave)))) (VP did not (VP appeal (PP to (NP anybody)))) .)"
npi_neg = "(S (NP The talk) (NP I) (VP did not (VP give (NP appealed) (PP to (NP anybody)))) .)"

# %%
Tree.fromstring(npi_pos)
# Out:
# Tree('S', [Tree('NP', [Tree('NP', ['The', 'talk']), Tree('SBAR', [Tree('S', [Tree('NP', ['I']), Tree('VP', ['gave'])])])]), Tree('VP', ['did', 'not', Tree('VP', ['appeal', Tree('PP', ['to', Tree('NP', ['anybody'])])])]), '.'])

# %%
Tree.fromstring(npi_neg)
# Out:
# Tree('S', [Tree('NP', ['The', 'talk']), Tree('NP', ['I']), Tree('VP', ['did', 'not', Tree('VP', ['give', Tree('NP', ['appealed']), Tree('PP', ['to', Tree('NP', ['anybody'])])])]), '.'])

# %% [markdown]
# ### DiscRNNG parser

# %%
npi_pos = "(S (NP (NP The talk) (SBAR (S (NP I) (VP gave)))) (VP did not (VP appeal (PP to (NP anybody)))) .)"
npi_neg = "(S (NP (NP The talk) (SBAR (S (NP I) (VP did not (VP give))))) (VP appealed (PP to (NP anybody))) .)"

# %%
Tree.fromstring(npi_pos)
# Out:
# Tree('S', [Tree('NP', [Tree('NP', ['The', 'talk']), Tree('SBAR', [Tree('S', [Tree('NP', ['I']), Tree('VP', ['gave'])])])]), Tree('VP', ['did', 'not', Tree('VP', ['appeal', Tree('PP', ['to', Tree('NP', ['anybody'])])])]), '.'])

# %%
Tree.fromstring(npi_neg)
# Out:
# Tree('S', [Tree('NP', [Tree('NP', ['The', 'talk']), Tree('SBAR', [Tree('S', [Tree('NP', ['I']), Tree('VP', ['did', 'not', Tree('VP', ['give'])])])])]), Tree('VP', ['appealed', Tree('PP', ['to', Tree('NP', ['anybody'])])]), '.'])

# %% [markdown]
# ## Garden path sentences
#
# The sentence
#
#     The student forgot the solution was in the back of the book.
#
# was taken from Jurafsky and Martin chapter 12 of 3rd edition.
#
# The correct parse is found by the generative rnng, in some occasions!

# %%
crf_tree = "(S (NP (NP The student) (VP forgot (NP the solution))) (VP was (PP in (NP (NP the back) (PP of (NP the book))))) .)"
disc_tree = "(S (NP (NP The student forgot) (SBAR (S (NP the solution) (VP was)))) (PP in (NP (NP the back) (PP of (NP the book)))) .)"
gen_tree = "(S (NP The student) (VP forgot (SBAR (S (NP the solution) (VP was (PP in (NP (NP the back) (PP of (NP the book)))))))) .)"

# %%
Tree.fromstring(crf_tree)
# Out:
# Tree('S', [Tree('NP', [Tree('NP', ['The', 'student']), Tree('VP', ['forgot', Tree('NP', ['the', 'solution'])])]), Tree('VP', ['was', Tree('PP', ['in', Tree('NP', [Tree('NP', ['the', 'back']), Tree('PP', ['of', Tree('NP', ['the', 'book'])])])])]), '.'])

# %%
Tree.fromstring(disc_tree)
# Out:
# Tree('S', [Tree('NP', [Tree('NP', ['The', 'student', 'forgot']), Tree('SBAR', [Tree('S', [Tree('NP', ['the', 'solution']), Tree('VP', ['was'])])])]), Tree('PP', ['in', Tree('NP', [Tree('NP', ['the', 'back']), Tree('PP', ['of', Tree('NP', ['the', 'book'])])])]), '.'])

# %%
Tree.fromstring(gen_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'student']), Tree('VP', ['forgot', Tree('SBAR', [Tree('S', [Tree('NP', ['the', 'solution']), Tree('VP', ['was', Tree('PP', ['in', Tree('NP', [Tree('NP', ['the', 'back']), Tree('PP', ['of', Tree('NP', ['the', 'book'])])])])])])])]), '.'])

# %% [markdown]
# Another one from Hale (2001):
#
#     The banker told about the buy-back resigned .

# %%
crf_tree = "(S (NP The banker) (VP told (SBAR about (SBAR (S the buy-back (VP resigned))))) .)"
disc_tree = "(S (NP The banker) (VP told (SBAR about (S (NP the buy-back) (VP resigned)))) .)"
gen_tree = "(S (NP The banker) (VP told (PP about (NP the buy-back resigned))) .)"

# %%
Tree.fromstring(crf_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('SBAR', ['about', Tree('SBAR', [Tree('S', ['the', 'buy-back', Tree('VP', ['resigned'])])])])]), '.'])

# %%
Tree.fromstring(disc_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('SBAR', ['about', Tree('S', [Tree('NP', ['the', 'buy-back']), Tree('VP', ['resigned'])])])]), '.'])

# %%
Tree.fromstring(gen_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('PP', ['about', Tree('NP', ['the', 'buy-back', 'resigned'])])]), '.'])

# %% [markdown]
# Another sentence completely:
#
#     The banker told about the buy-back quietly .

# %%
crf_tree = "(S (NP The banker) (VP told (NP about the buy-back) (ADVP quietly)) .)"
disc_tree = "(S (NP The banker) (VP told (PP about (NP the buy-back)) (ADVP quietly)) .)"
gen_tree = "(S (NP The banker) (VP told (PP about (NP the buy-back)) (ADVP quietly)) .)"

# %%
Tree.fromstring(crf_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('NP', ['about', 'the', 'buy-back']), Tree('ADVP', ['quietly'])]), '.'])

# %%
Tree.fromstring(disc_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('PP', ['about', Tree('NP', ['the', 'buy-back'])]), Tree('ADVP', ['quietly'])]), '.'])

# %%
Tree.fromstring(gen_tree)
# Out:
# Tree('S', [Tree('NP', ['The', 'banker']), Tree('VP', ['told', Tree('PP', ['about', Tree('NP', ['the', 'buy-back'])]), Tree('ADVP', ['quietly'])]), '.'])
