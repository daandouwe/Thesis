# %%
# %pylab inline
from scipy.stats import gamma
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/daan/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['gamma']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
fig, ax = plt.subplots(1, 1)
a1 = 6
a2 = 16
b1 = b2 = 1
c = 1./6
x = np.linspace(gamma.ppf(1e-10, a1),
                gamma.ppf(1-1e-10, a1), 100)

hrf = lambda x: gamma.pdf(x, a=a1, scale=b1) - c*gamma.pdf(x, a=a2, scale=b2)

ax.plot(x, hrf(x))
